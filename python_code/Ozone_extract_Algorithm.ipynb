# %%
# %matplotlib inline
import pandas as pd                #  data store and treat package pandas 
import matplotlib as mpl           # graph package
import matplotlib.pyplot as plt    # graph package
import numpy as np

# %%
Ozone_information = pd.read_csv('K_SW_Ozone.csv',encoding='euc-kr')
Ozone_information
# Out:
#      Ozone
# 0     0.01
# 1     0.01
# 2     0.01
# 3     0.01
# 4     0.01
# ..     ...
# 594   0.01
# 595   0.01
# 596   0.01
# 597   0.01
# 598   0.01
#
# [599 rows x 1 columns]

# %%
Nox_information_EPA = pd.read_csv('Indianapolis_2021(NO2).csv',encoding='euc-kr')
Nox_information_EPA
# Out:
#            Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 0    01/01/2021    AQS  180970078    3                                17.7
# 1    01/02/2021    AQS  180970078    3                                13.1
# 2    01/03/2021    AQS  180970078    3                                 9.3
# 3    01/04/2021    AQS  180970078    3                                29.4
# 4    01/05/2021    AQS  180970078    3                                25.2
# ..          ...    ...        ...  ...                                 ...
# 678  12/27/2021    AQS  180970087    2                                16.1
# 679  12/28/2021    AQS  180970087    2                                32.3
# 680  12/29/2021    AQS  180970087    2                                24.7
# 681  12/30/2021    AQS  180970087    2                                18.2
# 682  12/31/2021    AQS  180970087    2                                24.5
#
# ...

# %% [markdown]
# #### EPA 2021 인디에나폴리스 Ozone 값 하루 평균
# #### Ozone의 경우 실내 측정 모든 값이 0.1 로 측정 되기 때문에 리스트에 그대로 값을 적용시켰다.
# #### 2021.02.14 ~ 2021.02.18

# %%
EPA_Ozone = [0.026
,0.027
,0.024
,0.033
,0.037
]
Measurement_Ozone = [0.01,0.01,0.01,0.01,0.01]

# %%
plt.plot(EPA_Ozone,label='Outdoor(EPA)', marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(Measurement_Ozone,label='Indoor', marker='o', linestyle='solid') #Inoodr Data Our Measurment
# plt.plot(EPA_No2,'r--', Measurement_no2 ,'g-.') 
plt.legend(bbox_to_anchor=(1,1))
plt.title('Ozone')
plt.xlabel('day')
plt.ylabel('Contaminant Concentration / PPM')
plt.yticks(np.arange(0, 0.1, 0.01))
plt.xticks(np.arange(0, 5), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.savefig('Ozone.png',dpi=300,transparent=True,bbox_inches='tight')
plt.show()
