# %%
# %matplotlib inline
import pandas as pd                #  data store and treat package pandas 
import matplotlib as mpl           # graph package
import matplotlib.pyplot as plt    # graph package
import numpy as np

# %% [markdown]
# ## PM 2.5

# %%
# K-SW 값 
K_SW_PM_2_5 = [15.95,14.775, 15.216666666666667, 15.241666666666667, 15.325]
# Library 값
Li_PM2 = [7.558333333333334, 7.4, 7.05, 7.666666666666667, 6.4]
# Corec 값
Corec_PM2 = [17.441666666666666, 19.95, 22.425, 26.55, 18.016666666666666]
# Dining court 값 
Dining_PM2 = [39.791666666666664, 36.90833333333333, 45.09166666666667, 56.05, 86.15]

# EPA
EPA_PM2_5 = [14.1, 6.1, 5.2, 10.8, 21.1]

# %%
plt.plot(EPA_PM2_5,label='Outdoor(EPA)', marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(K_SW_PM_2_5,label='K-SW',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Li_PM2,label='Library',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Corec_PM2,label='Gym',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Dining_PM2,label='Dining Court',marker='o', linestyle='solid') #Inoodr Data Our Measurment
# plt.plot(EPA_No2,'r--', Measurement_no2 ,'g-.') 
plt.legend(bbox_to_anchor=(1,1))
plt.title('PM 2.5 Pollutant')
plt.xlabel('day')
plt.ylabel('Contaminant Concentration /ug/m3 ')
plt.ylim(0, 90)
plt.xticks(np.arange(0, 5, 1), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.savefig('PM2_1.png',dpi=300,transparent=True,bbox_inches='tight')
plt.show()
plt.plot(EPA_PM2_5,label='Outdoor(EPA)', marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(K_SW_PM_2_5,label='K-SW',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Li_PM2,label='Library',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Corec_PM2,label='Gym',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Dining_PM2,label='Dining Court',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.legend(bbox_to_anchor=(1,1))
plt.title('PM 2.5 Pollutant')
plt.xlabel('day')
plt.ylabel('Contaminant Concentration /ug/m3 ')
plt.xticks(np.arange(0, 5, 1), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.ylim(0, 30)
plt.savefig('PM2_2.png',dpi=300,transparent=True,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## PM 10

# %%
# K-SW 값
K_SW_PM_10 = [15.95,14.883333333333333,15.475, 15.5, 15.516666666666667]

# Library 값
Li_PM10 = [8.358333333333333, 7.991666666666666, 8.15, 8.016666666666667, 7.258333333333334]

# Corec 값
Corec_PM10 = [17.641666666666666, 20.725, 22.425, 26.708333333333332, 18.016666666666666]

# Dining court 값 
Dining_PM10 = [40.333333333, 37, 46.6666667, 56, 87.26666666666]


# EPA 
EPA_PM10 = [24,17,7,22,14]

# %%
plt.plot(EPA_PM2_5,label='Outdoor(EPA)', marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(K_SW_PM_10,label='K-SW',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Li_PM10,label='Library',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Corec_PM10,label='Gym',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Dining_PM2,label='Dining Court',marker='o', linestyle='solid') #Inoodr Data Our Measurment
# plt.plot(EPA_No2,'r--', Measurement_no2 ,'g-.') 
plt.legend(bbox_to_anchor=(1,1))
plt.title('PM 10 Pollutant')
plt.xlabel('day')
plt.ylabel('Contaminant Concentration /ug/m3 ')
plt.ylim(0, 90)
plt.xticks(np.arange(0, 5, 1), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.savefig('PM10_1.png',dpi=300,transparent=True,bbox_inches='tight')
plt.show()
plt.plot(EPA_PM2_5,label='Outdoor(EPA)', marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(K_SW_PM_10,label='K-SW',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Li_PM10,label='Library',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Corec_PM10,label='Gym',marker='o', linestyle='solid') #Inoodr Data Our Measurment
plt.plot(Dining_PM2,label='Dining Court',marker='o', linestyle='solid') #Inoodr Data Our Measurment
# plt.plot(EPA_No2,'r--', Measurement_no2 ,'g-.') 
plt.legend(bbox_to_anchor=(1,1))
plt.title('PM 10 Pollutant')
plt.xlabel('day')
plt.ylabel('Contaminant Concentration /ug/m3 ')
plt.ylim(0, 30)
plt.xticks(np.arange(0, 5, 1), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.savefig('PM10_2.png',dpi=300,transparent=True,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Co

# %%
# K-SW 값  
K_SW_CO = [1.6081250000000002, 1.5294083333333333, 1.0932000000000002, 1.0608000000000002, 1.0829250000000001]
# Library 값
Li_CO = [1.22525, 1.2549999999999997, 1.3220166666666666, 1.2842416666666665, 1.2086083333333335]
# Corec 값
Corec_CO = [0.23933333333333331, 0.03419166666666668, 0.021133333333333334, 0.01916666666666667, 0.01495833333333334]
# Dining court 값 
Di_CO = [1.0039916666666668, 1.0027083333333335, 1.030525, 1.2932166666666667, 1.537566666666667]

# EPA 
EPA_Co = [0.3,0.2,0.3,0.6,0.3]

# %%
plt.plot(EPA_Co,label='Outdoor(EPA)',marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(K_SW_CO,label='K-SW',marker='o', linestyle='solid') # K_SW_CO
plt.plot(Li_CO,label='Library',marker='o', linestyle='solid') #Library_CO
plt.plot(Corec_CO,label='Gym',marker='o', linestyle='solid') # Gym_CO
plt.plot(Di_CO,label='Dining Court',marker='o', linestyle='solid') # Dining_Court_CO

plt.legend(bbox_to_anchor=(1,1))
plt.title('Co Polluatant') # Change title nams 
plt.xlabel('day')
plt.ylabel('Contaminant Concentration / PPM')
plt.yticks(np.arange(0, 2.0, 0.1))
plt.xticks(np.arange(0, 5, 1), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.savefig('CO_1.png',dpi=300,transparent=True,bbox_inches='tight')
plt.show()

# %%
# %matplotlib inline
import pandas as pd                #  data store and treat package pandas 
import matplotlib as mpl           # graph package
import matplotlib.pyplot as plt    # graph package
import numpy as np
plt.plot(EPA_Co,label='Outdoor(EPA)',marker='o', linestyle='dashed', linewidth = "4.3") # Outdoor Data from EPA
plt.plot(K_SW_CO,label='K-SW',marker='o', linestyle='solid') # K_SW_CO
plt.plot(Li_CO,label='Library',marker='o', linestyle='solid') #Library_CO
plt.plot(Corec_CO,label='Gym',marker='o', linestyle='solid') # Gym_CO
plt.plot(Di_CO,label='Dining Court',marker='o', linestyle='solid') # Dining_Court_CO

plt.legend(bbox_to_anchor=(1,1))
plt.title('Co Polluatant') # Change title nams 
plt.xlabel('day')
plt.ylabel('Contaminant Concentration / PPM')
plt.yticks(np.arange(0, 2.0, 0.1))
plt.xticks(np.arange(0, 5, 1), labels=['1 day', '2 day',  '3 day', '4 day', '5 day'])
plt.show()
